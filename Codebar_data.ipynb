# %% [markdown]
# <a href="https://colab.research.google.com/github/itsvipa/ctm-codebar-nov-22-planning/blob/main/Codebar_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install thefuzz[speedup]
# !pip install py-stringsimjoin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting thefuzz[speedup]
#   Downloading thefuzz-0.19.0-py2.py3-none-any.whl (17 kB)
# Collecting python-levenshtein>=0.12
#   Downloading python_Levenshtein-0.20.8-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.20.8
#   Downloading Levenshtein-0.20.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (175 kB)
#      |████████████████████████████████| 175 kB 6.2 MB/s
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 36.8 MB/s
# Installing collected packages: rapidfuzz, Levenshtein, thefuzz, python-levenshtein
# Successfully installed Levenshtein-0.20.8 python-levenshtein-0.20.8 rapidfuzz-2.13.2 thefuzz-0.19.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting py-stringsimjoin
#   Downloading py_stringsimjoin-0.3.2.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from py-stringsimjoin) (1.2.0)
# Requirement already satisfied: pandas>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from py-stringsimjoin) (1.3.5)
# Collecting PyPrind>=2.9.3
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Collecting py_stringmatching>=0.2.1
#   Downloading py_stringmatching-0.4.2.tar.gz (661 kB)
#      |████████████████████████████████| 661 kB 46.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from py-stringsimjoin) (1.15.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.16.0->py-stringsimjoin) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.16.0->py-stringsimjoin) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.16.0->py-stringsimjoin) (2022.6)
# Building wheels for collected packages: py-stringsimjoin, py-stringmatching
#   Building wheel for py-stringsimjoin (setup.py) ... done
#   Created wheel for py-stringsimjoin: filename=py_stringsimjoin-0.3.2-cp37-cp37m-linux_x86_64.whl size=3724130 sha256=b57aa3b9412fe53e5af0d10d29273a3ec0fa2583bc8ec090636dedde6ea3140e
#   Stored in directory: /root/.cache/pip/wheels/7c/0d/a4/c0a779a4d196bed8ed41ca12be09a93e158e4fc974b59f9fd5
#   Building wheel for py-stringmatching (setup.py) ... done
#   Created wheel for py-stringmatching: filename=py_stringmatching-0.4.2-cp37-cp37m-linux_x86_64.whl size=2055525 sha256=a25ef1e63be670115039f48838fbb12e46ddf52f53ccd197b5cd9ebb82773c9b
#   Stored in directory: /root/.cache/pip/wheels/7e/12/86/46f9378ae730550dd2f89cad50880e70d66cabedd90074f2d2
# Successfully built py-stringsimjoin py-stringmatching
# Installing collected packages: PyPrind, py-stringmatching, py-stringsimjoin
# Successfully installed PyPrind-2.11.3 py-stringmatching-0.4.2 py-stringsimjoin-0.3.2

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import csv
import pandas
import random
import math
from os.path import exists
from concurrent.futures import ThreadPoolExecutor
from thefuzz import fuzz, process
import py_stringsimjoin as ssj
import py_stringmatching as sm

# %%
example_url = 'https://priceable.co.uk/product/32734'

# %%
def post_with_retry(url, payload, attempt=0, max_retries=3):
  result = requests.post(url, json=payload)
  if result.status_code == 503 and attempt < max_retries:
    return post_with_retry(url, payload, attempt + 1, max_retries)
  return result


def get_product_from_api(id):
  payload = {'id': "{}".format(id), 'retailer': "all"}
  url = "https://priceable.co.uk/api/product/"
  product_result = post_with_retry(url, payload)
  product = {}
  if product_result.status_code == 200:
    product =  product_result.json()['product']
  product['status_code'] = product_result.status_code
  return product

def get_related_products_from_api(id, name=''):
  payload = {'id': "{}".format(id), 'retailer': "all", 'name': name}
  url = "https://priceable.co.uk/api/related-products"
  return requests.post(url, json=payload).json()


def get_product(id, save_related=False):
  if id % 100 == 0:
    print('getting product ', id)
  product = get_product_from_api(id)
  if product['status_code'] == 200 and save_related:
    related = get_related_products_from_api(id, name=product['name'])
    product['related'] = [r['id'] for r in related]
  return product

def get_product_price_rows(product, product_field_names, price_field_names):
  product['price_count'] = len(product['pricing'])
  product_row = {k:product[k] for k in product_field_names}
  
  if product_row.get('skus'):
    product_row['skus'] = list(product_row['skus'].values())
  
  prices = [{**product_row, **p} for p in product['pricing']]
  price_rows = [{k:p[k] for k in price_field_names} for p in prices]

  return product_row, price_rows

# %%
product_field_names = [
    'id',
    'name',
    'measure_quantity',
    'measure_amount',
    'measure_unit',
#   'related',
    'skus',
    'price_count']

price_field_names = [
    'id',
    'name',
    'retailer',
    'available',
    'price',
    'price_per_unit',
    'price_unit_amount',
    'price_unit',
    'crawl_date']

def retrieve_statuses(start=0, end=10, status_file="status.csv.gz"):
  if exists(status_file):
    status_list = pandas.read_csv(status_file)['status'].values.tolist()
    current_status_size = len(status_list)
    
    if end > current_status_size:
      for i in range(current_status_size - 1, end):
        status_list.append(0)
    
    return status_list
  
  status_list = [0 for i in range(end)]
  return status_list


def write_statuses(status_list, status_file):
  df = pandas.DataFrame(status_list, columns=['status'])
  df.to_csv(status_file)

def retrieve_product_batch(ids):
  with ThreadPoolExecutor(max_workers=3) as executor:
    results = executor.map(get_product, ids)
  
  return { i:r for i, r in zip(ids, results) }

def retrieve_products(
    start=0,
    end=10,
    status_file="/content/drive/MyDrive/codebar_data/status.csv",
    product_file="/content/drive/MyDrive/codebar_data/products.csv",
    related_file="/content/drive/MyDrive/codebar_data/related.csv",
    price_file="/content/drive/MyDrive/codebar_data/prices.csv",
    batch_size=1000):

  status_list = retrieve_statuses(start, end, status_file)

  price_file_exists = exists(price_file)
  product_file_exists = exists(product_file)

  num_batches = math.ceil((end - start) / batch_size)

  with open(product_file, 'a', newline='') as product_csv, open(price_file, 'a', newline='') as price_csv:
    
    product_writer = csv.DictWriter(product_csv, fieldnames=product_field_names)
    price_writer = csv.DictWriter(price_csv, fieldnames=price_field_names)
    
    if not product_file_exists:
      product_writer.writeheader()
    
    if not price_file_exists:
      price_writer.writeheader()
    
    for batch_n in range(num_batches):
      print('executing batch: ', batch_n)
      batch_start = start + batch_n * batch_size
      batch_end = min(batch_start + batch_size, end)
      ids = [i for i in range(batch_start, batch_end) if status_list[i] not in (200, 404)]
      product_batch = retrieve_product_batch(ids)
      print('finished retrieving batch')
      price_rows = []
      product_rows = []
      product_price_rows = [
          get_product_price_rows(p, product_field_names, price_field_names)
          for p in product_batch.values() if p['status_code'] == 200]
      
      for product, prices in product_price_rows:
        product_rows.append(product)
        price_rows = price_rows + prices

      print('batch product count: ', len(product_rows))

      if len(product_rows) > 0:
        product_writer.writerows(product_rows)
        print('updated product file')

        price_writer.writerows(price_rows)
        print('updated price file')

      for k, v in product_batch.items():
        status_list[k] = v['status_code']
      write_statuses(status_list, status_file)
      print('updated status')

# %%
# retrieve_products(20000, 150000)

# %%
df = pandas.read_csv('/content/drive/MyDrive/codebar_data/products.csv')
df.sort_values(by=['price_count'], ascending=False).head(100)
# Out:
#           id                                                       name  \
# 8338   28798                              Tetley Original Tea Bags x240
# 12849  33714                         Hellmann's Real Squeezy Mayonnaise
# 8348   28808                                Sharp's Doom Bar Amber Ale
# 7710   28107                                  St Austell Proper Job IPA
# 8375   28836                         PG tips Original Tea Bags 240 pack
# ...      ...                                                        ...
# 11538  32243                              Border Dark Chocolate Gingers
# 14032  35024  Sensodyne Sensitivity & Gum Original Sensitive Toothpaste
# 7924   28346                     Schar Gluten Free Wholesome White Loaf
# 6670   26992                    Twinings Herbal Peppermint Tea Bags 20s
# 1213   21317                              McCain Lightly Spiced Wedges
#
#        measure_quantity measure_amount measure_unit  \
# 8338              240.0            750            g
# 12849               NaN            430           ml
# 8348                NaN            500           ml
# 7710                NaN            500           ml
# 8375              240.0            696            g
# ...                 ...            ...          ...
# 11538               NaN            150            g
# 14032               NaN             75           ml
# 7924                NaN            300            g
# 6670               20.0             40            g
# 1213                NaN            650            g
#
#                                                                                                       skus  \
# 8338   ['256093024', '3124932', '113676011', '32744', '48468011', '5000208069897', 'b40a4ef3-fcfb-454d-...
# 12849  ['7010738', '111631011', '910000020309', '264365273', '13959011', 'c9bda77f-9187-4a1a-b8f8-48751...
# 8348   ['260342577', '6691085', '38703011', '122199011', '910001057649', '662439b2-7eba-4731-9efc-2414f...
# 7710   ['264792757', '7707305', '55542011', '910001696166', '5028403155146', '15452ba9-1fd5-4b8e-913f-a...
# 8375   ['287195415', '2827018', '280635011', '910001958290', '13240011', '8712100712494', 'f41c1606-17a...
# ...                                                                                                    ...
# 11538  ['6327553', '481759011', '483739011', '1000134959173', '304416699', '6dce3854-bf2c-41f7-aa65-980...
# 14032  ['1000108538926', '303014342', '7954218', '451224011', '445892011', '80221f52-57bc-42b9-ad14-178...
# 7924   ['7791746', '320902011', '300389011', '910002521596', '290819809', '905dd6f4-05ea-4a32-8e45-d14d...
# 6670   ['254198819', '20186', '6617766', '39876011', '113653011', 'eca4a1e7-0541-45d1-9f0d-27ded19aa9eb...
# 1213   ['1000216498434', '517918011', '306501043', '8014502', '11620011', 'a21bd7b8-249d-424e-98e7-2bd3...
#
#        price_count
# 8338             8
# 12849            8
# 8348             8
# 7710             8
# 8375             8
# ...            ...
# 11538            7
# 14032            7
# 7924             7
# 6670             7
# 1213             7
#
# [100 rows x 7 columns]

# %% [markdown]
# To Do:
# - Get Related product info
# - Write something to download all the products
# - Figure out a method to match products with nutritional api
#
# - Trim down the csvs

# %%
nutrition = pandas.read_csv('/content/drive/MyDrive/codebar_data/ukproducts.csv')
products = pandas.read_csv('/content/drive/MyDrive/codebar_data/products.csv')

# %%
ssj.profile_table_for_join(products)
# Out:
#                    Unique values  Missing values  \
# Attribute
# id                81670 (100.0%)        0 (0.0%)
# name               78814 (96.5%)        0 (0.0%)
# measure_quantity     132 (0.16%)  68345 (83.68%)
# measure_amount       970 (1.19%)  23791 (29.13%)
# measure_unit          93 (0.11%)  24276 (29.72%)
# skus              81638 (99.96%)        0 (0.0%)
# price_count            9 (0.01%)        0 (0.0%)
#
#                                                                     Comments
# Attribute
# id                            This attribute can be used as a key attribute.
# name
# measure_quantity  Joining on this attribute will ignore 68345 (83.68%) rows.
# measure_amount    Joining on this attribute will ignore 23791 (29.13%) rows.
# measure_unit      Joining on this attribute will ignore 24276 (29.72%) rows.
# skus
# price_count

# %%
ssj.profile_table_for_join(nutrition)
# Out:
#                               Unique values  Missing values  \
# Attribute
# _id                          87049 (100.0%)        0 (0.0%)
# categories_properties_tags     1196 (1.37%)     680 (0.78%)
# nutrient_levels                1378 (1.58%)    1089 (1.25%)
# nutrient_levels_tags            179 (0.21%)    1089 (1.25%)
# quantity                       2967 (3.41%)  67958 (78.07%)
# nutriments                   64755 (74.39%)     680 (0.78%)
# product_name                 64821 (74.46%)    5122 (5.88%)
# ecoscore_data                85515 (98.24%)     905 (1.04%)
# stores_tags                     891 (1.02%)  58766 (67.51%)
# stores                         1017 (1.17%)  65003 (74.67%)
# nutrition_score_beverage           3 (0.0%)      698 (0.8%)
# nutrition_data_prepared_per        3 (0.0%)    1245 (1.43%)
# nutrition_grades_tags             8 (0.01%)    1089 (1.25%)
# vitamins_tags                   417 (0.48%)  51509 (59.17%)
# unknown_nutrients_tags           54 (0.06%)    1786 (2.05%)
# minerals_tags                   341 (0.39%)  51509 (59.17%)
# id                           87043 (99.99%)        3 (0.0%)
# nutrition_data_per                 3 (0.0%)    1245 (1.43%)
# nutrient_levels_tags.1          179 (0.21%)    1089 (1.25%)
# nutrition_score_debug           110 (0.13%)   17407 (20.0%)
# ecoscore_tags                     8 (0.01%)     905 (1.04%)
# completeness                     63 (0.07%)        0 (0.0%)
# product_name_en              62607 (71.92%)     7923 (9.1%)
# categories_properties           1998 (2.3%)     680 (0.78%)
# amino_acids_tags                 15 (0.02%)  51509 (59.17%)
#
#                                                                                Comments
# Attribute
# _id                                      This attribute can be used as a key attribute.
# categories_properties_tags      Joining on this attribute will ignore 680 (0.78%) rows.
# nutrient_levels                Joining on this attribute will ignore 1089 (1.25%) rows.
# nutrient_levels_tags           Joining on this attribute will ignore 1089 (1.25%) rows.
# quantity                     Joining on this attribute will ignore 67958 (78.07%) rows.
# nutriments                      Joining on this attribute will ignore 680 (0.78%) rows.
# product_name                   Joining on this attribute will ignore 5122 (5.88%) rows.
# ecoscore_data                   Joining on this attribute will ignore 905 (1.04%) rows.
# stores_tags                  Joining on this attribute will ignore 58766 (67.51%) rows.
# stores                       Joining on this attribute will ignore 65003 (74.67%) rows.
# nutrition_score_beverage         Joining on this attribute will ignore 698 (0.8%) rows.
# nutrition_data_prepared_per    Joining on this attribute will ignore 1245 (1.43%) rows.
# nutrition_grades_tags          Joining on this attribute will ignore 1089 (1.25%) rows.
# vitamins_tags                Joining on this attribute will ignore 51509 (59.17%) rows.
# unknown_nutrients_tags         Joining on this attribute will ignore 1786 (2.05%) rows.
# minerals_tags                Joining on this attribute will ignore 51509 (59.17%) rows.
# id
# nutrition_data_per             Joining on this attribute will ignore 1245 (1.43%) rows.
# nutrient_levels_tags.1         Joining on this attribute will ignore 1089 (1.25%) rows.
# nutrition_score_debug         Joining on this attribute will ignore 17407 (20.0%) rows.
# ecoscore_tags                   Joining on this attribute will ignore 905 (1.04%) rows.
# completeness
# product_name_en                 Joining on this attribute will ignore 7923 (9.1%) rows.
# categories_properties           Joining on this attribute will ignore 680 (0.78%) rows.
# amino_acids_tags             Joining on this attribute will ignore 51509 (59.17%) rows.

# %%
alnum_tok = sm.AlphanumericTokenizer(return_set=True)

# %%
nutrition['new_key_attr'] = range(0, len(nutrition))

output_pairs = ssj.jaccard_join(
    products, nutrition, 
    'id', 'new_key_attr', 'name', 'product_name', 
    alnum_tok, 0.3, 
    l_out_attrs=['name'], r_out_attrs=['product_name'])
# Out:
# 0% [############################# ] 100% | ETA: 00:00:00

# %%
deduped_pairs = output_pairs.sort_values('_sim_score', ascending=False).drop_duplicates(['l_id'])
deduped_pairs
# Out:
#          _id   l_id  r_new_key_attr  \
# 30616  30616  27071           34361
# 22318  22318  38962           25683
# 22778  22778  25386           26154
# 4018    4018  26121            4179
# 22689  22689  94806           26012
# ...      ...    ...             ...
# 36114  36114  86230           39124
# 36115  36115  99794           39124
# 36116  36116  49749           39125
# 36118  36118  52854           39125
# 36119  36119  53946           39125
#
#                                                     l_name  \
# 30616                                               Sprite
# 22318                                            Coca-Cola
# 22778                                              IRN-BRU
# 4018                           Lucozade Zero Pink Lemonade
# 22689               Willie's Cacao Sea Salt Caramel Pearls
# ...                                                    ...
# 36114            L'Oreal Elvive Colour Protect Conditioner
# 36115                L'Oreal Elvive Colour Protect Shampoo
# 36116                      Feather & Down Massage To Sleep
# 36118                        Feather & Down Sleep Well Set
# 36119  Feather & Down Sweet Dreams Sleep Body Butter 300Ml
#
#                                r_product_name  _sim_score
# 30616                                  Sprite         1.0
# 22318                               Coca Cola         1.0
# 22778                                 IRN BRU         1.0
# 4018              Zero Lucozade Pink Lemonade         1.0
# 22689  Willie's Cacao Sea Salt Caramel Pearls         1.0
# ...                                       ...         ...
# 36114                   Elvive Colour Protect         0.5
# 36115                   Elvive Colour Protect         0.5
# 36116             Feather & Down Sleep Butter         0.5
# 36118             Feather & Down Sleep Butter         0.5
# 36119             Feather & Down Sleep Butter         0.5
#
# [20436 rows x 6 columns]
